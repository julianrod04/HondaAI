# %%
import carla
import random

# %%
# Core elements in carla are: actors, blueprints, worlds, and clients
client = carla.Client('localhost', 2000)
# Set the map to Town06.
# client.load_world('Town06')

# %%
# Get the world object
world = client.get_world()
# carla_map = world.get_map() # Prints the map name
# world.get_actors() # Prints all actors in the world
# world.get_actors().filter('*vehicle*') # Prints all vehicles in the world

# %%
# Get the blueprint library and filter for the vehicle blueprints.
# Lists catalog of sensors, props, vehicles, etc.
vehicle_bps = world.get_blueprint_library()
# print(vehicle_bps)

# Print vehicle_bps to text file in alphabetical order
# with open('vehicle_bps.txt', 'w') as f:
#     for bp in sorted(vehicle_bps, key=lambda x: x.id):
#         f.write(f"{bp.id}\n")

# %%
# Retrieve the spectator object
# Print id and type of spectator
spectator = world.get_spectator()
# print(spectator)

# A transform is a location and rotation. Gets transform from most recent frame.
transform = spectator.get_transform()

# print(transform)
# print(transform.location)
# print(transform.rotation)

# Update the spectator's location and rotation to the center lane of our scenario
# default_location = carla.Location(x=17.092312, y=244.485397, z=0.500000)
# default_rotation = carla.Rotation(pitch=360.000000, yaw=1.780838, roll=0.000000)

# Top-down view of our scenario
default_location = carla.Location(x=115, y=244.485397, z=100.000000)
default_rotation = carla.Rotation(pitch=270.000000, yaw=270, roll=0.000000)
spectator.set_transform(carla.Transform(default_location, default_rotation))

# %%
carla_map = world.get_map()
# Get the waypoint at the spectator's location
waypoint = carla_map.get_waypoint(transform.location)

# Extract the location and rotation from the waypoint
waypoint_location = waypoint.transform.location
waypoint_rotation = waypoint.transform.rotation
print(waypoint_location)
print(waypoint_rotation)
# Add 0.5 to the location height
# waypoint_location.z += .5

# spectator.set_transform(carla.Transform(waypoint_location, waypoint_rotation))

# Get the lane width
# print(f"Lane width: {waypoint.lane_width} meters") # Lanes are 3.5 meters wide
# Out:
# Location(x=114.999969, y=244.564850, z=0.000000)
# Rotation(pitch=0.000000, yaw=0.019546, roll=0.000000)

# %%
spawn_points = world.get_map().get_spawn_points()
print(spawn_points)
# Out:
# [<carla.libcarla.Transform object at 0x75a4ec6e4cc0>, <carla.libcarla.Transform object at 0x75a4ec6e4e40>, <carla.libcarla.Transform object at 0x75a4ec6e4ec0>, <carla.libcarla.Transform object at 0x75a4ec6e4f40>, <carla.libcarla.Transform object at 0x75a4ec6e4fc0>, <carla.libcarla.Transform object at 0x75a4ec6e5040>, <carla.libcarla.Transform object at 0x75a4ec6e50c0>, <carla.libcarla.Transform object at 0x75a4ec6e5140>, <carla.libcarla.Transform object at 0x75a4ec6e51c0>, <carla.libcarla.Transform object at 0x75a4ec6e52c0>, <carla.libcarla.Transform object at 0x75a4ec6e5340>, <carla.libcarla.Transform object at 0x75a4ec6e53c0>, <carla.libcarla.Transform object at 0x75a4ec6e5440>, <carla.libcarla.Transform object at 0x75a4ec6e54c0>, <carla.libcarla.Transform object at 0x75a4ec6e5540>, <carla.libcarla.Transform object at 0x75a4ec6e55c0>, <carla.libcarla.Transform object at 0x75a4ec6e5640>, <carla.libcarla.Transform object at 0x75a4ec6e5240>, <carla.libcarla.Transform object at 0x75a4ec6e56c0>, <carla.libcarla.Transform object at 0x75a4ec6e5740>, <carla.libcarla.Transform object at 0x75a4ec6e57c0>, <carla.libcarla.Transform object at 0x75a4ec6e5840>, <carla.libcarla.Transform object at 0x75a4ec6e58c0>, <carla.libcarla.Transform object at 0x75a4ec6e5940>, <carla.libcarla.Transform object at 0x75a4ec6e59c0>, <carla.libcarla.Transform object at 0x75a4ec6e5a40>, <carla.libcarla.Transform object at 0x75a4ec6e5ac0>, <carla.libcarla.Transform object at 0x75a4ec6e5b40>, <carla.libcarla.Transform object at 0x75a4ec6e5bc0>, <carla.libcarla.Transform object at 0x75a4ec6e5c40>, <carla.libcarla.Transform object at 0x75a4ec6e5cc0>, <carla.libcarla.Transform object at 0x75a4ec6e5d40>, <carla.libcarla.Transform object at 0x75a4ec6e5dc0>, <carla.libcarla.Transform object at 0x75a4ec6e5e40>, <carla.libcarla.Transform object at 0x75a4ec6e5ec0>, <carla.libcarla.Transform object at 0x75a4ec6e5f40>, <carla.libcarla.Transform object at 0x75a4ec6e5fc0>, <carla.libcarla.Transform object at 0x75a4ec6e6040>, <carla.libcarla.Transform object at 0x75a4ec6e60c0>, <carla.libcarla.Transform object at 0x75a4ec6e6140>, <carla.libcarla.Transform object at 0x75a4ec6e61c0>, <carla.libcarla.Transform object at 0x75a4ec6e6240>, <carla.libcarla.Transform object at 0x75a4ec6e62c0>, <carla.libcarla.Transform object at 0x75a4ec6e6340>, <carla.libcarla.Transform object at 0x75a4ec6e63c0>, <carla.libcarla.Transform object at 0x75a4ec6e6440>, <carla.libcarla.Transform object at 0x75a4ec6e64c0>, <carla.libcarla.Transform object at 0x75a4ec6e6540>, <carla.libcarla.Transform object at 0x75a4ec6e65c0>, <carla.libcarla.Transform object at 0x75a4ec6e6640>, <carla.libcarla.Transform object at 0x75a4ec6e66c0>, <carla.libcarla.Transform object at 0x75a4ec6e6740>, <carla.libcarla.Transform object at 0x75a4ec6e67c0>, <carla.libcarla.Transform object at 0x75a4ec6e6840>, <carla.libcarla.Transform object at 0x75a4ec6e68c0>, <carla.libcarla.Transform object at 0x75a4ec6e6940>, <carla.libcarla.Transform object at 0x75a4ec6e69c0>, <carla.libcarla.Transform object at 0x75a4ec6e6a40>, <carla.libcarla.Transform object at 0x75a4ec6e6ac0>, <carla.libcarla.Transform object at 0x75a4ec6e6b40>, <carla.libcarla.Transform object at 0x75a4ec6e6bc0>, <carla.libcarla.Transform object at 0x75a4ec6e6c40>, <carla.libcarla.Transform object at 0x75a4ec6e6cc0>, <carla.libcarla.Transform object at 0x75a4ec6e6d40>, <carla.libcarla.Transform object at 0x75a4ec6e6dc0>, <carla.libcarla.Transform object at 0x75a4ec6e6e40>, <carla.libcarla.Transform object at 0x75a4ec6e6ec0>, <carla.libcarla.Transform object at 0x75a4ec6e6f40>, <carla.libcarla.Transform object at 0x75a4ec6e6fc0>, <carla.libcarla.Transform object at 0x75a4ec6e7040>, <carla.libcarla.Transform object at 0x75a4ec6e70c0>, <carla.libcarla.Transform object at 0x75a4ec6e7140>, <carla.libcarla.Transform object at 0x75a4ec6e71c0>, <carla.libcarla.Transform object at 0x75a4ec6e7240>, <carla.libcarla.Transform object at 0x75a4ec6e72c0>, <carla.libcarla.Transfor ...

# %%
ego_vehicle = world.spawn_actor(ego_vehicle_bp, spawn_point)
